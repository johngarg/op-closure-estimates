# %% [markdown]
# # Example notebook
#
# We publish our results as `Pandas` dataframes that can be readily queried. Below we show how to access these, but point readers to the extensive documentation for more information on how to use them: https://pandas.pydata.org/docs/index.html.

# %%
import os
import pandas as pd

# Change working directory of the notebook to access the Python code
os.chdir('../python')

# %% [markdown]
# Initialising the data to pass to the dataframes can take a little while. On my machine the next cell takes about 5 mins to run.

# %%
# %%time

from database import get_tree_level_dataframe, get_loop_level_dataframe
# Out:
# CPU times: user 5min 12s, sys: 623 ms, total: 5min 13s
# Wall time: 5min 17s

# %% [markdown]
# Call these functions to return the dataframes. For example

# %%
df = get_loop_level_dataframe()

# %% [markdown]
# The dataframe contains many keys. These are summarised below.
#
# | Key                         | Description                                                                               |
# |-----------------------------|-------------------------------------------------------------------------------------------|
# | `smeft_op`                  | The `sympy` symbol representing the coefficient of the SMEFT operator being matched on to |
# | `smeft_label`               | The label of the SMEFT operator                                                           |
# | `smeft_flavour`             | The flavour indices of the SMEFT operator                                                 |
# | `smeft_op_expr`             | The symbolic expression implementing the SMEFT-LEFT matching provided in the paper        |
# | `process`                   | The decay process generated in LaTeX                                                      |
# | `gamma`                     | The symbolic decay rate                                                                   |
# | `left_dimension`            | The dimension of the LEFT operator generated                                              |
# | `gamma_coeff_1`             | The decay rate with the dimensionless coefficient set to 1                                |
# | `left_op`                   | The label of the LEFT operator driving the decay process                                  |
# | `left_flavour`              | The flavour indices of the LEFT operator                                                  |
# | `lambda_limit`              | The symbolic lower limit on the underlying new-physics scale                              |
# | `lambda_limit_coeff_1`      | The numeric lower limit on the underlying new-physics scale with coefficient set to 1     |
# | `lifetime_limit`            | The experimental lifetime limit in years                                                  |
# | `lifetime_limit_ref`        | The reference from which the experimental bound is taken                                  |
# | `dim`                       | A copy of `left_dimension`                                                                |
# | `matrix_elem`               | The nuclear matrix element relevant to the nucleon decay calculation                      |
# | `fieldstring_label`         | The label of the field-string operator                                                    |
# | `fieldstring_flavour`       | The flavour indices of the field string                                                   |
# | `latex`                     | The LaTeX expression of the matching estimate                                             |
# | `gamma_fieldstring_coeff`   | The decay rate with the matching estimate pasted in for the SMEFT coefficient             |
# | `gamma_fieldstring_coeff_1` | Same as `gamma_fieldstring_coeff` but for field-string coefficient set to 1               |

# %%
df.keys()
# Out:
# Index(['smeft_op', 'smeft_label', 'smeft_flavour', 'smeft_op_expr', 'process',
#        'gamma', 'left_dimension', 'gamma_coeff_1', 'left_op', 'left_flavour',
#        'lambda_limit', 'lambda_limit_coeff_1', 'lifetime_limit',
#        'lifetime_limit_ref', 'dim', 'matrix_elem', 'fieldstring_label',
#        'fieldstring_flavour', 'latex', 'gamma_fieldstring_coeff',
#        'gamma_fieldstring_coeff_1'],
#       dtype='object')

# %% [markdown]
# This dataframe can be queried in the usual way. For example, suppose we want to see contributions to $p \to \pi^{0} e^{+}$ UV models generating operator 11 at tree level

# %%
df[(df.fieldstring_label == "11") & (df.process == "p \\to \\pi^{0} e^{+}")]
# Out:
#            smeft_op smeft_label smeft_flavour  \
# 0    K_duql_0_0_0_0        duql          1111
# 8    K_duql_0_0_0_0        duql          1111
# 37   C_qqql_0_0_0_0        qqql          1111
# 38   C_qqql_0_0_0_0        qqql          1111
# 39   C_qqql_0_0_0_0        qqql          1111
# 177  C_qqql_0_1_0_0        qqql          1211
# 178  C_qqql_0_1_0_0        qqql          1211
# 179  C_qqql_0_1_0_0        qqql          1211
# 237  C_qqql_0_2_0_0        qqql          1311
# 238  C_qqql_0_2_0_0        qqql          1311
# 239  C_qqql_0_2_0_0        qqql          1311
#
#                                          smeft_op_expr              process  \
# 0                                       K_duql_0_0_0_0  p \to \pi^{0} e^{+}
# 8                                       K_duql_0_0_0_0  p \to \pi^{0} e^{+}
# 37                            0.9746875*C_qqql_0_0_0_0  p \to \pi^{0} e^{+}
# 38                            0.9746875*C_qqql_0_0_0_0  p \to \pi^{0} e^{+}
# 39                            0.9746875*C_qqql_0_0_0_0  p \to \pi^{0} e^{+}
# 177                               0.225*C_qqql_0_1_0_0  p \to \pi^{0} e^{+}
# 178                               0.225*C_qqql_0_1_0_0  p \to \pi^{0} e^{+}
# 179                               0.225*C_qqql_0_1_0_0  p \to \pi^{0} e^{+}
# 237  C_qqql_0_2_0_0*(0.00149597634375 - 0.003274212...  p \to \pi^{0} e^{+}
# 238  C_qqql_0_2_0_0*(0.00149597634375 - 0.003274212...  p \to \pi^{0} e^{+}
# 239  C_qqql_0_2_0_0*(0.00149597634375 - 0.003274212...  p \to \pi^{0} e^{+}
#
#                                                  gamma  left_dimension  \
# 0    0.000452573724054281*Abs(K_duql_0_0_0_0/LAMBDA...               6
# 8    0.000452573724054281*Abs(K_duql_0_0_0_0/LAMBDA...               6
# 37   0.000387774971411024*Abs(C_qqql_0_0_0_0/LAMBDA...               6
# 38   0.000387774971411024*Abs(C_qqql_0_0_0_0/LAMBDA...               6
# 39   0.000387774971411024*Abs(C_qqql_0_0_0_0/LAMBDA...               6
# 177  2.06639821421001e-5*Abs(C_qqql_0_1_0_0/LAMBDA*...               6
# 178  2.06639821421001e-5*Abs(C_qqql_0_1_0_0/LAMBDA*...               6
# 179  2.06639821421001e-5*Abs(C_qqql_0_1_0_0/LAMBDA*...               6
# 237  5.28933120085494e-9*Abs(C_qqql_0_2_0_0/LAMBDA*...               6
# 238  5.28933120085494e-9*Abs(C_qqql_0_2_0_0/LAMBDA*...               6
# 239  5.28933120085494e-9*Abs(C_qqql_0_2_0_0/LAMBDA*...               6
#
#                       gamma_coeff_1   left_op left_flavour  ...  \
# 0    0.000452573724054281/LAMBDA**4  S,RL_duu         1111  ...
# 8    0.000452573724054281/LAMBDA**4  S,RL_duu         1111  ...
# 37   0.000387774971411024/LAMBDA**4  S,LL_duu         1111  ...
# 38   0.000387774971411024/LAMBDA**4  S,LL_duu         1111  ...
# 39   0.000387774971411024/LAMBDA**4  S,LL_duu         1111  ...
# 177   2.06639821421001e-5/LAMBDA**4  S,LL_duu         1111  ...
# 178   2.06639821421001e-5/LAMBDA**4  S,LL_duu         1111  ...
# 179   2.06639821421001e-5/LAMBDA**4  S,LL_duu         1111  ...
# 237   5.28933120085494e-9/LAMBDA**4  S,LL_duu         1111  ...
# 238   5.28933120085494e-9/LAMBDA**4  S,LL_duu         1111  ...
# 239   5.28933120085494e-9/LAMBDA**4  S,LL_duu         1111  ...
#
#            lifetime_limit_ref dim  matrix_elem fieldstring_label  \
# 0    Super-Kamiokande:2020wjk   6     0.224860                11
# 8    Super-Kamiokande:2020wjk   6     0.224860                11
# 37   Super-Kamiokande:2020wjk   6    -0.213546                11
# 38   Super-Kamiokande:2020wjk   6    -0.213546                11
# 39   Super-Kamiokande:2020wjk   6    -0.213546                11
# 177  Super-Kamiokande:2020wjk   6    -0.213546                11
# 178  Super-Kamiokande:2020wjk   6    -0.213546                11
# 179  Super-Kamiokande:2020wjk   6    -0.213546                11
# 237  Super-Kamiokande:2020wjk   6    -0.213546                11
# 238  Super-Kamiokande:2020wjk   6    -0.213546                11
# 239  Super-Kamiokande:2020wjk   6    -0.213546                11
#
#      fieldstring_flavour                                              latex  \
# 0                   1111  \frac{1}{16\pi^2} (y_u)^{q} \mathcal{C}_{11}^{...
# 8                   1111  \frac{1}{16\pi^2} (y_u)^{q} \mathcal{C}_{11}^{...
# 37                  1111  \sum_{u^\prime} \frac{1}{16\pi^2} V_{r u^\prim...
# 38                  1112  \sum_{u^\prime} \frac{1}{16\pi^2} V_{r u^\prim...
# 39                  1113  \sum_{u^\prime} \frac{1}{16\pi^2} V_{r u^\prim...
# 177                 1121  \sum_{u^\prime} \frac{1}{16\pi^2} V_{r u^\prim...
# 178                 1122  \sum_{u^\prime} \frac{1}{16\pi^2} V_{r u^\prim...
# 179                 1123  \sum_{u^\prime} \frac{1}{16\pi^2} V_{r u^\prim...
# 237                 1131  \sum_{u^\prime} \frac{1}{16\pi^2} V_{r u^\prim...
# 238                 1132  \sum_{u^\prime} \frac{1}{16\pi^2} V_{r u^\prim...
# 239                 1133  \sum_{u^\prime} \frac{1}{16\pi^2} V_{r u^\prim...
#
#                                gamma_fieldstring_coeff  \
# 0    8.33678243400018e-19*Abs(C_11,_0_0_0_0/LAMBDA*...
# 8    8.33678243400018e-19*Abs(C_11,_0_0_0_0/LAMBDA*...
# 37   3.19400517543617e-18*Abs(C_11,_0_0_0_0/LAMBDA*...
# 38   6.72861211049174e-17*Abs(C_11,_0_0_0_1/LAMBDA*...
# 39   4.85341425929933e-17*Abs(C_11,_0_0_0_2/LAMBDA*...
# 177  1.70204037838818e-19*Abs(C_11,_0_0_1_0/LAMBDA*...
# 178  3.58558263795071e-18*Abs(C_11,_0_0_1_1/LAMBDA*...
# 179  2.58631611053803e-18*Abs(C_11,_0_0_1_2/LAMBDA*...
# 237  4.35668943992252e-23*Abs(C_11,_0_0_2_0/LAMBDA*...
# 238  9.17796675865155e-22*Abs(C_11,_0_0_2_1/LAMBDA*...
# 239  6.62015791761242e-22*Abs(C_11,_0_0_2_2/LAMBDA*...
#
#           gamma_fieldstring_coeff_1             exp_ratio    bound_saturation
# 0    8.33678243400018e-19/LAMBDA**4  1.52563118542203e+47   0.261013429098834
# 8    8.33678243400018e-19/LAMBDA**4  1.52563118542203e+47   0.261013429098834
# 37   3.19400517543617e-18/LAMBDA**4  5.84502947104819e+47    1.00000000000000
# 38   6.72861211049174e-17/LAMBDA**4  1.23133601621999e+49   0.420734406226997
# 39   4.85341425929933e-17/LAMBDA**4  8.88174809451778e+48  0.0555860983375884
# 177  1.70204037838818e-19/LAMBDA**4  3.11473389245036e+46    1.00000000000000
# 178  3.58558263795071e-18/LAMBDA**4  6.56161622744980e+47    1.00000000000000
# 179  2.58631611053803e-18/LAMBDA**4  4.73295848228459e+47   0.222344393350354
# 237  4.35668943992252e-23/LAMBDA**4  7.97274167505821e+42   0.234042856394710
# 238  9.17796675865155e-22/LAMBDA**4  1.67956791683323e+44   0.234042856394710
# 239  6.62015791761242e-22/LAMBDA**4  1.21148889892307e+44  0.0325478840205915
#
# [11 rows x 23 columns]

# %% [markdown]
# What lower bound can we set on the scale $\Lambda$ characterising these models, for unit operator coefficient?

# %%
df[(df.fieldstring_label == "11") & (df.process == "p \\to \\pi^{0} e^{+}")].sort_values(by="lambda_limit_coeff_1", ascending=False).iloc[0]
# Out:
# smeft_op                                                        C_qqql_0_0_0_0
# smeft_label                                                               qqql
# smeft_flavour                                                             1111
# smeft_op_expr                                         0.9746875*C_qqql_0_0_0_0
# process                                                    p \to \pi^{0} e^{+}
# gamma                        0.000387774971411024*Abs(C_qqql_0_0_0_0/LAMBDA...
# left_dimension                                                               6
# gamma_coeff_1                                   0.000387774971411024/LAMBDA**4
# left_op                                                               S,LL_duu
# left_flavour                                                              1111
# lambda_limit                         1873243117644.49*sqrt(Abs(C_11,_0_0_0_1))
# lambda_limit_coeff_1                                          1873243117644.49
# lifetime_limit                           23999999999999998693805543689027584.0
# lifetime_limit_ref                                    Super-Kamiokande:2020wjk
# dim                                                                          6
# matrix_elem                                                          -0.213546
# fieldstring_label                                                           11
# fieldstring_flavour                                                       1112
# latex                        \sum_{u^\prime} \frac{1}{16\pi^2} V_{r u^\prim...
# gamma_fieldstring_coeff      6.72861211049174e-17*Abs(C_11,_0_0_0_1/LAMBDA*...
# gamma_fieldstring_coeff_1                       6.72861211049174e-17/LAMBDA**4
# exp_ratio                                                 1.23133601621999e+49
# bound_saturation                                             0.420734406226997
# Name: 38, dtype: object

# %% [markdown]
# And we see that the best bound from $p \to \pi^{0} e^{+}$ on models generating operator 16 at tree level is 1873243117644.49. The bound is on the field-string flavour indices 1112. The bound saturation is 0.42, which shows that a better limit can be set from another decay modes.

# %% [markdown]
# In the paper, we present the bound saturation for different flavours of the field-string operator 16. Here we reproduce that analysis.
#
# First calculate the bound saturation

# %%
# Import LAMBDA to set later
from tables import LAMBDA

def calc_exp_ratio(row):
    """Function to calculate the ratio of the decay rate to its experimental bound."""
    inv_gev_per_year = 7.625e30
    value_in_inv_gev = lambda x: inv_gev_per_year * x

    # Set LAMBDA to 1 since it cancels in the full ratio anyway
    gamma = row.gamma_fieldstring_coeff_1.subs({LAMBDA: 1.})
    gamma_limit = 1.0 / value_in_inv_gev(row.lifetime_limit)

    ratio = gamma / gamma_limit
    return ratio

df["exp_ratio"] = df.apply(calc_exp_ratio, axis=1)
# A dictionary mapping a tuple (fieldstring_label, fieldstring_flavour) to a float (the max ratio of the decay rate to the experimental limit)
max_ratio_dict = df[["fieldstring_label", "fieldstring_flavour", "exp_ratio"]].groupby(by=["fieldstring_label", "fieldstring_flavour"]).max().to_dict()["exp_ratio"]

def calc_bound_saturation(row):
    """Calculate the double ratio: exp_ratio / max(exp_ratio)."""
    return row.exp_ratio / max_ratio_dict[(row.fieldstring_label, row.fieldstring_flavour)]

df["bound_saturation"] = df.apply(calc_bound_saturation, axis=1)

# %% [markdown]
# We can query the dataframe for just those rows that are related to operator 16, and create restructure the table to look like the correlation plots presented in the paper.

# %%
pd.pivot_table(
    df[df.fieldstring_label == '16'],
    values='bound_saturation',
    index=['fieldstring_label', 'fieldstring_flavour'],
    columns=['process'],
    aggfunc=lambda x: float(max(x)), 
    fill_value=0,
)
# Out:
# process                                n \to K^{0} \nu  n \to \eta^{0} \nu  \
# fieldstring_label fieldstring_flavour
# 16                1111                        0.000132            0.000756
#                   1112                        0.019496            0.001273
#                   1113                        0.019496            0.001209
#                   1121                        0.019496            0.001273
#                   1122                        0.019496            0.001273
#                   1123                        0.019496            0.001209
#                   1131                        0.019496            0.001209
#                   1132                        0.019496            0.001209
#                   1133                        0.039613            0.000673
#                   1211                        0.019496            0.001273
#                   1212                        0.019496            0.001273
#                   1213                        0.022282            0.000302
#                   1221                        0.019496            0.001273
#                   1222                        0.019496            0.001273
#                   1223                        0.022282            0.000302
#                   1231                        0.022282            0.000302
#                   1232                        0.022282            0.000302
#                   1233                        0.022282            0.000302
#                   1311                        0.019496            0.000177
#                   1312                        0.022282            0.000177
#                   1313                        0.022282            0.000177
#                   1321                        0.022282            0.000177
#                   1322                        0.022282            0.000177
#                   1323                        0.022282            0.000177
#                   1331                        0.022282            0.000177
#                   1332                        0.022282            0.000177
#                   1333                        0.022282            0.000177
#
# process                                n \to \pi^{-} e^{+}  n \to \pi^{0} \nu  \
# fieldstring_label fieldstring_flavour
# 16                1111                            0.110259           0.043607
#                   1112                            0.046390           0.073389
#                   1113                            0.044071           0.069720
#                   1121                            0.046390           0.073389
#                   1122                            0.046390           0.073389
#                   1123                            0.044071           0.069720
#                   1131                            0.044071           0.069720
#                   1132                            0.044071           0.069720
#                   1133                            0.024516           0.038784
#                   1211                            0.000000           0.073389
#                   1212                            0.000000           0.073389
#                   1213                            0.000000           0.017430
#                   1221                            0.000000           0.073389
#                   1222                            0.000000           0.073389
#                   1223                            0.000000           0.017430
#                   1231                            0.000000           0.017430
#                   1232                            0.000000           0.017430
#                   1233                            0.000000           0.017430
#                   1311                            0.000000           0.010206
#                   1312                            0.000000           0.010206
#                   1313                            0.000000           0.010206
#                   1321                            0.000000           0.010206
#                   1322                            0.000000           0.010206
#                   1323                            0.000000           0.010206
#                   1331                            0.000000           0.010206
#                   1332                            0.000000           0.010206
#                   1333                            0.000000           0.010206
#
# process                                p \to K^{+} \nu  p \to K^{0} e^{+}  \
# fieldstring_label fieldstring_flavour
# 16                1111                        0.006749           0.000048
#                   1112                        1.000000           0.007185
#                   1113                        1.000000           0.007185
#                   1121                        1.000000           0.007185
#                   1122                        1.000000           0.007185
#                   1123                        1.000000           0.007185
#                   1131                        1.000000           0.007185
#                   1132                        1.000000           0.007185
#                   1133                        1.000000           0.003997
#                   1211                        1.000000           0.000000
#                   1212                        1.000000           0.000000
#                   1213                        1.000000           0.000000
#                   1221                        1.000000           0.000000
#                   1222                        1.000000           0.000000
#                   1223                        1.000000           0.000000
#                   1231                        1.000000           0.000000
#                   1232                        1.000000           0.000000
#                   1233                        1.000000           0.000000
#                   1311                        1.000000           0.000000
#                   1312                        1.000000           0.000000
#                   1313                        1.000000           0.000000
#                   1321                        1.000000           0.000000
#                   1322                        1.000000           0.000000
#                   1323                        1.000000           0.000000
#                   1331                        1.000000           0.000000
#                   1332                        1.000000           0.000000
#                   1333                        1.000000           0.000000
#
# process                                p \to \eta^{0} e^{+}  \
# fieldstring_label fieldstring_flavour
# 16                1111                             0.052841
#                   1112                             0.022232
#                   1113                             0.021121
#                   1121                             0.022232
#                   1122                             0.022232
#                   1123                             0.021121
#                   1131                             0.021121
#                   1132                             0.021121
#                   1133                             0.011749
#                   1211                             0.000000
#                   1212                             0.000000
#                   1213                             0.000000
#                   1221                             0.000000
#                   1222                             0.000000
#                   1223                             0.000000
#                   1231                             0.000000
#                   1232                             0.000000
#                   1233                             0.000000
#                   1311                             0.000000
#                   1312                             0.000000
#                   1313                             0.000000
#                   1321                             0.000000
#                   1322                             0.000000
#                   1323                             0.000000
#                   1331                             0.000000
#                   1332                             0.000000
#                   1333                             0.000000
#
# process                                p \to \pi^{+} \nu  p \to \pi^{0} e^{+}
# fieldstring_label fieldstring_flavour
# 16                1111                          0.007696             1.000000
#                   1112                          0.012952             0.420734
#                   1113                          0.012305             0.399704
#                   1121                          0.012952             0.420734
#                   1122                          0.012952             0.420734
#                   1123                          0.012305             0.399704
#                   1131                          0.012305             0.399704
#                   1132                          0.012305             0.399704
#                   1133                          0.006845             0.222344
#                   1211                          0.012952             0.000000
#                   1212                          0.012952             0.000000
#                   1213                          0.003076             0.000000
#                   1221                          0.012952             0.000000
#                   1222                          0.012952             0.000000
#                   1223                          0.003076             0.000000
#                   1231                          0.003076             0.000000
#                   1232                          0.003076             0.000000
#                   1233                          0.003076             0.000000
#                   1311                          0.001801             0.000000
#                   1312                          0.001801             0.000000
#                   1313                          0.001801             0.000000
#                   1321                          0.001801             0.000000
#                   1322                          0.001801             0.000000
#                   1323                          0.001801             0.000000
#                   1331                          0.001801             0.000000
#                   1332                          0.001801             0.000000
#                   1333                          0.001801             0.000000
